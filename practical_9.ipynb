# %%
from textblob import TextBlob

# %%
reviews = [
  "I love this produt, it is amaazing!",
  "This is the worst purchase I ever made.",
  "The product is okay, not great."
]

# %%
for review in reviews:
  blob = TextBlob(review)
  polarity = blob.sentiment.polarity
  if polarity > 0:
    sentiment = "positive"
  elif polarity < 0:
    sentiment = "Negative"
  else:
    sentiment = "Neutral"
  print(f"Review: {review}\nSentiment: {sentiment}\nPolarity: {polarity}\n")
# Out:
# Review: I love this produt, it is amaazing!
# Sentiment: positive
# Polarity: 0.625
#
# Review: This is the worst purchase I ever made.
# Sentiment: Negative
# Polarity: -1.0
#
# Review: The product is okay, not great.
# Sentiment: positive
# Polarity: 0.04999999999999999
